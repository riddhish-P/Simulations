# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio

# %%
num_particles = 5
particle_pos = np.random.rand(2)#np.array([[1,2],[3,4]],dtype=float)
print (particle_pos)
# Out:
# [0.27780501 0.44890121]

# %%
class Particle:
    def __init__(self, pos, vel):
        self.pos = pos
        self.vel = vel

# %%
p1 = Particle(np.array([1.,2.5]),np.array([0.0,0.0]))
#p2 = Particle(np.array([4.,3.]),np.array([0.2,0.0]))

all_particles = [p1]

# %%
# num_particles = 4
# all_particles = []
# for npar in range(num_particles):
#     all_particles.append(Particle(2.5*np.random.rand(2) , 0.9*np.random.randn(2)+0.1 ))

# %%
def update_pos(all_particles, t_step):
    for particle in all_particles:
        r_sq = ((particle.pos[0]-2.5)**2) + ((particle.pos[1]-2.5)**2)
        r = np.sqrt(r_sq)
        xacc = acc * np.sin(particle.pos[0]-2.5)/dist)
        
        particle.vel[0] -= np.sign(particle.pos[0]-2.5) * xacc * t_step/2
        particle.vel[1] -= np.sign(particle.pos[1]-2.5) * yacc * t_step/2

        #particle.vel[1] += -2.0 * t_step/2

        #particle.vel[0] -= np.sign(particle.pos[0]-2.5)*xacc*t_step/2.
        #particle.vel[1] -= np.sign(particle.pos[1]-2.5)*yacc*t_step/2.
        
        #print (particle.pos)
        particle.pos[0] += particle.vel[0]*t_step
        particle.pos[1] += particle.vel[1]*t_step
        
        

    return

# %%
def check_wall_col(all_particles):
    for particle in all_particles:
        if particle.pos[0] > 4.9 or particle.pos[0]<0.1:
            particle.vel[0] *= -1
        if particle.pos[1] > 4.9 or particle.pos[1]<0.1:
            particle.vel[1] *= -1
        
    return

# %%
update_pos(all_particles,0.1)

# %%
#plt.scatter( [p.pos[0] for p in all_particles] , [p.pos[1] for p in all_particles] )
#plt.xlim(0,5)
#plt.ylim(0,5)

# %%
# particle_pos1 = np.copy(particle_pos)
# traj_pos = []
# traj_pos.append(particle_pos1)
# for i in range (10):
#     particle_pos1 = update_pos(particle_pos1)
#     traj_pos.append(particle_pos1)

    
#print (np.shape(traj_pos))
#print (traj_pos)

# %%
for i in range(200):
    fig = plt.figure(figsize=(6,6))
    ax = fig.add_subplot(111)#, projection='3d',computed_zorder=False)
    ax.scatter([p.pos[0] for p in all_particles] , [p.pos[1] for p in all_particles])
    plt.xlim(0,5)
    plt.ylim(0,5)
    #plt.pause(0.05)
    #plt.grid()
    
    circle1 = plt.Circle((2.5, 2.5), 1, color='r',fill=False)
    circle2 = plt.Circle((2.5, 2.5), 1.5, color='blue',fill=False)
#    circle3 = plt.Circle((1, 1), 0.2, color='g', clip_on=False)

    #fig, ax = plt.subplots() # note we must use plt.subplots, not plt.subplot
    # (or if you have an existing figure)
    # fig = plt.gcf()
    # ax = fig.gca()

    ax.add_patch(circle1)
    ax.add_patch(circle2)
#    ax.add_patch(circle3)
    
    plt.savefig(f'two_particles_{i}.png')
    for reps in range(2):
        update_pos(all_particles,0.1)
        check_wall_col(all_particles)
    
    #plt.clear()
# Out:
# /var/folders/mn/w20y_zw94j54lh9gpndqh2rh0000gn/T/ipykernel_41270/425885381.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=(6,6))

# %%
with imageio.get_writer('two_part.gif', mode='I') as writer:
    for i in range(200):
        image = imageio.imread(f'two_particles_{i}.png')
        writer.append_data(image)
